# %%
print('hi')
# Out:
# hi

# %%
print('hello')
# Out:
# hello

# %%
s='codegnan'
print(s[2])
# Out:
# d

# %%
print(s[-3])
# Out:
# n

# %%
print(s[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(s[10])
#
# IndexError: string index out of range

# %%
s[0:4:1]
# Out:
# 'code'

# %%
s[2:5]
# Out:
# 'deg'

# %%
s[:5]
# Out:
# 'codeg'

# %%
s[5:]
# Out:
# 'nan'

# %%
s[::2]
# Out:
# 'cdga'

# %%
s[-6:-2]
# Out:
# 'degn'

# %%
s[-3:-10]
# Out:
# ''

# %%
s[-11:-6]
# Out:
# 'co'

# %%
s[5:15]
# Out:
# 'nan'

# %%
s[5:10:-1]
# Out:
# ''

# %%
s[::-1]
# Out:
# 'nangedoc'

# %%
s[-1:-9:-1]
# Out:
# 'nangedoc'

# %%
s[:-3:-1]
# Out:
# 'na'

# %%
s[5:-7:1]
# Out:
# ''
